# %%
import pandas as pd

file = 'PCMOVENDPEND.xlsx'

df = pd.read_excel(file, engine='openpyxl')

# %%
import pyperclip as pc

colunas = df.columns.to_list()

pc.copy(colunas)

# %%
import pandas as pd

file2 = 'PCPRODUT.xlsx'

df2 = pd.read_excel(file2, engine='openpyxl')

# %%
import pyperclip as pc

colunas2 = df2.columns.to_list()

pc.copy(colunas2)

# %%
import pandas as pd

file3 = 'PCTIPOOS.xlsx'

df3 = pd.read_excel(file3, engine='openpyxl')

# %%
import pyperclip as pc

colunas3 = df3.columns.to_list()

pc.copy(colunas3)

# %%
df
# Out:
#               DATA
# 0       2025-01-02
# 1       2025-01-02
# 2       2025-01-02
# 3       2025-01-02
# 4       2025-01-02
# ...            ...
# 519844  2025-03-31
# 519845  2025-03-31
# 519846  2025-03-31
# 519847  2025-03-31
# 519848  2025-03-31
#
# [519849 rows x 1 columns]
